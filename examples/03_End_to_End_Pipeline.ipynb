# %% [markdown]
# # End-to-End Pipeline Execution
# This notebook shows how to trigger a full DSEngine run from code, using a YAML configuration file. The pipeline runner handles loading, inspecting, running all steps, and generating a self-contained HTML report.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from ds_engine.utils import pipeline_runner

# %% [markdown]
# ### Executing the Pipeline
# Ensure you have created `configs/pipeline.yml` and specified your experiment. The pipeline runner will execute all steps sequentially and save outputs to the configured output directory.

# %%
config_path = '../configs/pipeline.yml'
experiment_name = '03_End_to_End_Pipeline'

# Uncomment the following to run if the config is ready:
exit_code = pipeline_runner.run(config_path, experiment_name)
print('Pipeline exited with code:', exit_code)
# Out:
# ╔══════════════════════════════════════════════════════════════╗
# ║  DSEngine  |  Experiment: 03_End_to_End_Pipeline        ║
# ║  Config  : ../configs/pipeline.yml                         ║
# ║  Started : 2026-03-20 13:07:13                             ║
# ╚══════════════════════════════════════════════════════════════╝
# ► Loading data...
# [2026-03-20 13:07:13] [WARNING] [ds_engine] Column name changed: 'MedInc' -> 'medinc'
# [2026-03-20 13:07:13] [WARNING] [ds_engine] Column name changed: 'HouseAge' -> 'houseage'
# [2026-03-20 13:07:13] [WARNING] [ds_engine] Column name changed: 'AveRooms' -> 'averooms'
# [2026-03-20 13:07:13] [WARNING] [ds_engine] Column name changed: 'AveBedrms' -> 'avebedrms'
# [2026-03-20 13:07:13] [WARNING] [ds_engine] Column name changed: 'Population' -> 'population'
# [2026-03-20 13:07:13] [WARNING] [ds_engine] Column name changed: 'AveOccup' -> 'aveoccup'
# [2026-03-20 13:07:13] [WARNING] [ds_engine] Column name changed: 'Latitude' -> 'latitude'
# ...
