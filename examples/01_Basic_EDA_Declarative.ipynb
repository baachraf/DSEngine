# %% [markdown]
# # Basic Exploratory Data Analysis (Declarative)
# This notebook acts as an interactive runner for DSEngine. It strictly follows the declarative philosophy: it uses the pre-existing YAML configuration defined in `configs/01_basic_eda.yml`.

# %%
# Load and display the experiment configuration
with open('../configs/01_basic_eda.yml', 'r') as f:
    print(f.read())
# Out:
# 01_Basic_EDA_Declarative:
#   data:
#     source: 'examples/datasets/diabetes.csv'
#   steps:
#     - name: 'data_overview'
#       type: 'summary'
#       params:
#         include_skew: true
#         include_kurtosis: true
#     - name: 'check_missing'
#       type: 'missing'
#       params:
#         plot_type: 'both'
#     - name: 'column_distributions'
#       type: 'distributions'
#       params:
#         plot_type: 'both'
#         bins: 30
#         show_normal_overlay: true
#   output:
#     path: 'examples/outputs/'
#     format: ['json']
#     save_plots: true

# %% [markdown]
# ### Execute the Pipeline

# %%
import sys, os, glob
from IPython.display import HTML, display

sys.path.insert(0, os.path.abspath('..'))
from ds_engine.utils import pipeline_runner

# 1. Run the pipeline based purely on the pre-existing YAML config
config_path = '../configs/01_basic_eda.yml'
experiment_name = '01_Basic_EDA_Declarative'

print(f"Executing pipeline for '{experiment_name}' using: {config_path}...")
pipeline_runner.run(config_path, experiment_name)
# Out:
# Executing pipeline for '01_Basic_EDA_Declarative' using: ../configs/01_basic_eda.yml...
# ╔══════════════════════════════════════════════════════════════╗
# ║  DSEngine  |  Experiment: 01_Basic_EDA_Declarative      ║
# ║  Config  : ../configs/01_basic_eda.yml                     ║
# ║  Started : 2026-03-24 20:28:10                             ║
# ╚══════════════════════════════════════════════════════════════╝
# ► Loading data...
#   Source  : D:\OneDrive - STEPLESMOSENSESARL\PlesmoSense-CENTAN\Code\ACHRAF_Private\DS_Engine\examples\datasets\diabetes.csv
#   Shape   : 442 rows x 11 columns
#   Columns : age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, target
# ► Pre-flight inspection...
#   ✔  No fatal issues.
# ► Running steps (3 total):
#   [1/3] data_overview    (summary       ) ... done  (0.03s)
#   [2/3] check_missing    (missing       ) ... done  (0.09s)
#   [3/3] column_distributions (distributions ) ... done  (0.81s)
# ► Saving outputs...
#   Plots : 12 figure(s) → D:\OneDrive - STEPLESMOSENSESARL\PlesmoSense-CENTAN\Code\ACHRAF_Private\DS_Engine\examples\outputs\01_Basic_EDA_Declarative\20260324_202810\plots/
#   JSON  : D:\OneDrive - STEPLESMOSENSESARL\PlesmoSense-CENTAN\Code\ACHRAF_Private\DS_Engine\examples\outputs\01_Basic_EDA_Declarative\20260324_202810\report.json
# ╔══════════════════════════════════════════════════════════════╗
# ║  ✔  Run complete                                             ║
# ║  Steps  : 3 completed, 0 failed                             ║
# ║  Time   : 8.10s total                                        ║
# ║  Output : outputs\01_Basic_EDA_Declarative\20260324_202810   ║
# ╚══════════════════════════════════════════════════════════════╝
# 0

# %% [markdown]
# ### View the Report

# %%
# 2. Find and display the generated HTML report
output_dirs = sorted(glob.glob(f'./outputs/{experiment_name}/*'))

if output_dirs:
    latest_report = os.path.join(output_dirs[-1], 'report.html')
    if os.path.exists(latest_report):
        display(HTML(latest_report))
    else:
        print("Report not found.")
else:
    print("No output directory found.")
# Out:
# Report not found.
